# %% [markdown]
# # ⚛️ Kapitel 22: Jupiter Notebook**Autor:** Christian Berrang
# **Datum:** 2025-06-18
# **DOI:** 10.5281/zenodo.17874830
#
# Dieses Notebook enthält die zentralen Axiome, Formeln, empirischen Validierungen und Teilchenvorhersagen des Frequenzgesetzes – maschinenlesbar und direkt ausführbar.

# %% [markdown]
# ## 1. Axiome des Frequenzgesetzes

# %%
# Axiome als Python-Dictionary (direkt aus dem JSON übernommen)
axiome = [
    {"id": "A0", "name": "Das Nullfeld", "formal": "ΔΦ = 0", "text": "Prägeometrischer Zustand vor jeder Manifestation."},
    {"id": "A1", "name": "Frequenz ist primär", "formal": "f [Hz] primär", "text": "Frequenz ist die strukturierende Wiederholung selbst. Energie ist abgeleitet."},
    {"id": "A2", "name": "Information durch Unterscheidung", "formal": "I ∝ ΔΦ", "text": "ΔΦ=0 kein Sein. ΔΦ≠0 Realität beginnt."},
    {"id": "A3", "name": "Zeit ist emergent", "formal": "T = ΔΦ / f", "text": "Zeit emergiert aus Phasenfortschritt. T=1/f ist Spezialfall bei ΔΦ=2π."},
    {"id": "A4", "name": "Energie ist abgeleitet", "formal": "E = h·f", "text": "Energie ist messbare Wirkung der Frequenz."},
    {"id": "A5", "name": "Masse ist gebundene Frequenz", "formal": "m = h·f / c²", "text": "Masse ist stabilisierter Frequenzzustand. Frequenz erzeugt Masse."},
    {"id": "A6", "name": "Frequenzerhaltung", "formal": "∑ h·f_i = const", "text": "Frequenz bleibt erhalten. Energieerhaltung folgt als Konsequenz."}
]

import pandas as pd
df_axiome = pd.DataFrame(axiome)
df_axiome

# %% [markdown]
# ## 2. Kernformeln

# %%
formeln = [
    {"id": "F1", "name": "Emergente Zeit", "latex": "T = \Delta\Phi / f", "status": "emergent"},
    {"id": "F2", "name": "Masse", "latex": "m = hf/c^2", "status": "abgeleitet"},
    {"id": "F3", "name": "Energie", "latex": "E = hf", "status": "abgeleitet"},
    {"id": "F4", "name": "Frequenzerhaltung", "latex": "\sum E_i = \sum h f_i = const", "status": "Konsequenz"}
]
df_formeln = pd.DataFrame(formeln)
df_formeln

# %% [markdown]
# ## 3. Empirische Validierung (Vergleich mit PDG-Werten)

# %%
validierung = [
    {"Teilchen": "Elektron", "Frequenz (Hz)": 1.2358e20, "berechnet (kg)": 9.110932192767744e-31, "PDG (kg)": 9.1093837015e-31, "Abweichung %": 0.016999},
    {"Teilchen": "Proton", "Frequenz (Hz)": 2.2687e23, "berechnet (kg)": 1.672598467853389e-27, "PDG (kg)": 1.67262192369e-27, "Abweichung %": 0.001402},
    {"Teilchen": "Neutron", "Frequenz (Hz)": 2.2718e23, "berechnet (kg)": 1.674883942023771e-27, "PDG (kg)": 1.67492749804e-27, "Abweichung %": 0.002600},
    {"Teilchen": "Myon", "Frequenz (Hz)": 2.5554e22, "berechnet (kg)": 1.8839679661270994e-28, "PDG (kg)": 1.88353162e-28, "Abweichung %": 0.023166},
    {"Teilchen": "Higgs", "Frequenz (Hz)": 3.018e25, "berechnet (kg)": 2.225019692326675e-25, "PDG (kg)": 2.225e-25, "Abweichung %": 0.000885}
]
df_valid = pd.DataFrame(validierung)
df_valid

# %%
# Grafische Darstellung der Abweichungen
import matplotlib.pyplot as plt

plt.figure(figsize=(8,4))
plt.bar(df_valid["Teilchen"], df_valid["Abweichung %"], color="skyblue")
plt.ylabel("Abweichung vom PDG-Wert (%)")
plt.title("Empirische Validierung der Masseberechnung m = hf/c²")
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# ## 4. Vorhergesagte Teilchen

# %%
vorhersagen = [
    {"Name": "Berrangium Ω", "Symbol": "Ω", "Frequenz (Hz)": 3.907e21, "Energie (MeV)": 16.2, "Masse (kg)": 2.880434704413625e-29, "Widmung": "Christian Berrang"},
    {"Name": "Stöcker-Teilchen", "Symbol": "S", "Frequenz (Hz)": 1.27e24, "Energie (MeV)": 530, "Masse (kg)": 9.36307160124214e-27, "Widmung": "Prof. Dr. Horst Stöcker, FIAS Frankfurt — Mentor"}
]
df_vorher = pd.DataFrame(vorhersagen)
df_vorher

# %% [markdown]
# ## 5. Kausalkette

# %%
kette = [
    "Nullfeld (ΔΦ=0)",
    "Erste Phasendifferenzierung",
    "Frequenz f [primär]",
    "Phase ΔΦ",
    "Zeit T=ΔΦ/f [emergent]",
    "Energie E=hf [abgeleitet]",
    "Masse m=hf/c² [abgeleitet]",
    "Gravitation"
]
for step in kette:
    print("→", step)

# %% [markdown]
# ## 6. Naturkonstanten

# %%
constants = {"h": 6.62607015e-34, "c": 299792458.0, "G": 6.6743e-11, "k_B": 1.380649e-23}
for name, value in constants.items():
    print(f"{name} = {value:.6e}")

# %% [markdown]
# ---
# *Dieses Notebook wurde automatisch aus dem JSON-Kern generiert.*
