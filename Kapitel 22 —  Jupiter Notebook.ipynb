# %% [markdown]
# # Kapitel 22 — Jupiter Notebook
# ## Frequenzgesetz | Maschinenlesbar extrahiert
#
# **Autor:** Christian Berrang
# **Datum:** 18. Juni 2025
# **DOI:** 10.5281/zenodo.17874830

# %% [markdown]
# ## 0. Imports

# %%
import pandas as pd
import matplotlib.pyplot as plt
import json
print('Imports OK')

# %% [markdown]
# ## 1. Axiome

# %%
axiome = [
    {'id':'A0','name':'Das Nullfeld','formal':'N := {DeltaPhi=0}','text':'Praegeometrischer Zustand.'},
    {'id':'A1','name':'Frequenz ist primaer','formal':'f [Hz]','text':'Frequenz ist strukturierende Wiederholung.'},
    {'id':'A2','name':'Information','formal':'I prop DeltaPhi','text':'DeltaPhi=0 kein Sein. DeltaPhi!=0 Realitaet.'},
    {'id':'A3','name':'Zeit ist emergent','formal':'T = DeltaPhi / f','text':'Zeit emergiert aus Phase.'},
    {'id':'A4','name':'Energie abgeleitet','formal':'E = h*f','text':'Energie ist Wirkung der Frequenz.'},
    {'id':'A5','name':'Masse = Frequenz','formal':'m = h*f / c**2','text':'Masse ist stabilisierte Frequenz.'},
    {'id':'A6','name':'Frequenzerhaltung','formal':'sum h*fi = const','text':'Frequenz bleibt erhalten.'}
]
pd.DataFrame(axiome)

# %% [markdown]
# ## 2. Kernformeln

# %%
formeln = [
    {'id':'F1','formel':'T = DeltaPhi / f','status':'emergent'},
    {'id':'F2','formel':'m = h*f / c**2','status':'abgeleitet'},
    {'id':'F3','formel':'E = h*f','status':'abgeleitet'},
    {'id':'F4','formel':'sum Ei = const','status':'Konsequenz'}
]
pd.DataFrame(formeln)

# %% [markdown]
# ## 3. Empirische Validierung

# %%
validierung = [
    {'Teilchen':'Elektron','Frequenz (Hz)':1.2358e20,'berechnet (kg)':9.110932e-31,'PDG (kg)':9.1093837015e-31,'Abweichung %':0.017},
    {'Teilchen':'Proton',  'Frequenz (Hz)':2.2687e23,'berechnet (kg)':1.672598e-27,'PDG (kg)':1.67262192369e-27,'Abweichung %':0.0014},
    {'Teilchen':'Neutron', 'Frequenz (Hz)':2.2718e23,'berechnet (kg)':1.674884e-27,'PDG (kg)':1.67492749804e-27,'Abweichung %':0.0026},
    {'Teilchen':'Myon',    'Frequenz (Hz)':2.5554e22,'berechnet (kg)':1.883968e-28,'PDG (kg)':1.88353162e-28,  'Abweichung %':0.023},
    {'Teilchen':'Higgs',   'Frequenz (Hz)':3.018e25, 'berechnet (kg)':2.225020e-25,'PDG (kg)':2.225e-25,       'Abweichung %':0.0009}
]
df_valid = pd.DataFrame(validierung)
df_valid

# %%
plt.figure(figsize=(8,4))
plt.bar(df_valid['Teilchen'], df_valid['Abweichung %'], color='steelblue')
plt.ylabel('Abweichung %')
plt.title('Validierung: m = h*f / c**2')
plt.grid(axis='y', alpha=0.5)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 4. Vorhergesagte Teilchen

# %%
vorhersagen = [
    {'Name':'Berrangium Omega','Frequenz (Hz)':3.907e21,'Energie (MeV)':16.2,'Masse (kg)':2.881e-29,'Widmung':'Christian Berrang'},
    {'Name':'Stoecker-Teilchen','Frequenz (Hz)':1.27e23,'Energie (MeV)':530,'Masse (kg)':9.36e-28,'Widmung':'Prof. Dr. Horst Stoecker, FIAS Frankfurt'}
]
pd.DataFrame(vorhersagen)

# %% [markdown]
# ## 5. Kausalkette

# %%
kette = ['Nullfeld','Frequenz f','Phase DeltaPhi','Zeit T=DeltaPhi/f','Energie E=hf','Masse m=hf/c**2','Gravitation']
for i,s in enumerate(kette): print(f'{i} -> {s}')

# %% [markdown]
# ## 6. Naturkonstanten

# %%
c = {'h':6.62607015e-34,'c':2.99792458e8,'G':6.6743e-11,'k_B':1.380649e-23}
for n,v in c.items(): print(f'{n} = {v:.6e}

# %% [markdown]
# ---
# *Frequenzgesetz v8.0 | Christian Berrang | DOI: 10.5281/zenodo.17874830*
